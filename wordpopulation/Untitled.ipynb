# %%
import pandas as pd 
import numpy as np

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                  147  141381703                  43  ...  125   B  Major
# 1                   48  133716286                  48  ...   92  C#  Major
# 2                  113  140003974                  94  ...  138   F  Major
# 3                  100  800840817                 116  ...  170   A  Major
# 4                   50  303236322                  84  ...  144   A  Minor
# ..                 ...        ...                 ...  ...  ...  ..    ...
# 948                  0   91473363                  61  ...  144   A  Major
# 949                  0  121871870                   4  ...  166  F#  Major
# 950                  0   73513683                   2  ...   92  C#  Major
# 951                  0  133895612                  29  ...   97  C#  Major
# 952                  2   96007391                  27  ...   90   E  Minor
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0               80         89       83             31                   0
# 1               71         61       74              7                   0
# 2               51         32       53             17                   0
# 3               55         58       72             11                   0
# 4               65         23       80             14                  63
# ..             ...        ...      ...            ...                 ...
# 948             60         24       39             57                   0
# 949             42          7       24             83                   1
# 950             80         81       67              4                   0
# 951             82         67       77              8                   0
# 952             61         32       67             15                   0
#
#      liveness_%  speechiness_%
# 0             8              4
# 1            10              4
# 2            31              6
# 3            11             15
# 4            11              6
# ..          ...            ...
# 948           8              3
# 949          12              6
# 950           8              6
# 951          12              5
# 952          11              5
#
# [953 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
df.head(10)
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
sns.scatterplot(y="in_spotify_charts",x="in_apple_playlists",data=df)
# Out:
# <Axes: xlabel='in_apple_playlists', ylabel='in_spotify_charts'>

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
df.dropna()
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                  147  141381703                  43  ...  125   B  Major
# 1                   48  133716286                  48  ...   92  C#  Major
# 2                  113  140003974                  94  ...  138   F  Major
# 3                  100  800840817                 116  ...  170   A  Major
# 4                   50  303236322                  84  ...  144   A  Minor
# ..                 ...        ...                 ...  ...  ...  ..    ...
# 948                  0   91473363                  61  ...  144   A  Major
# 949                  0  121871870                   4  ...  166  F#  Major
# 950                  0   73513683                   2  ...   92  C#  Major
# 951                  0  133895612                  29  ...   97  C#  Major
# 952                  2   96007391                  27  ...   90   E  Minor
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0               80         89       83             31                   0
# 1               71         61       74              7                   0
# 2               51         32       53             17                   0
# 3               55         58       72             11                   0
# 4               65         23       80             14                  63
# ..             ...        ...      ...            ...                 ...
# 948             60         24       39             57                   0
# 949             42          7       24             83                   1
# 950             80         81       67              4                   0
# 951             82         67       77              8                   0
# 952             61         32       67             15                   0
#
#      liveness_%  speechiness_%
# 0             8              4
# 1            10              4
# 2            31              6
# 3            11             15
# 4            11              6
# ..          ...            ...
# 948           8              3
# 949          12              6
# 950           8              6
# 951          12              5
# 952          11              5
#
# [817 rows x 24 columns]

# %%
 X= df[['artist_count', 'released_year',
       'released_month', 'released_day', 'in_spotify_playlists',
       'in_spotify_charts','bpm',
        'danceability_%', 'valence_%', 'energy_%',
       'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']]

# %%
y = df['streams']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1, random_state=900)

# %%
lm = LogisticRegression()

# %%
X_test
# Out:
#      artist_count  released_year  released_month  released_day  \
# 94              1           2020               6             5
# 470             1           1986               1             1
# 935             2           2022              11             4
# 774             2           2022               5            13
# 727             2           2011               1             1
# ..            ...            ...             ...           ...
# 554             3           2021               3            19
# 95              2           2023               5            12
# 890             1           2022               3            11
# 395             1           2015               1             1
# 136             3           2022              12             2
#
#      in_spotify_playlists  in_spotify_charts  bpm  danceability_%  valence_%  \
# 94                     31                 39   88              53         34
# 470                   888                  0  180              51         87
# 935                  1338                  0  158              84         33
# 774                  3028                  0  140              92         78
# 727                 42798                  0  129              86         75
# ..                    ...                ...  ...             ...        ...
# 554                 14140                  0   90              63         49
# 95                   2175                 23  143              83         69
# 890                  1189                  6  120              90         73
# 395                 17852                  4  147              51         62
# 136                  1682                 46  119              75         48
#
#      energy_%  acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 94         47               9                   0          83              4
# 470        58              36                   0          18              4
# 935        36               2                   0          39             59
# 774        57              46                   0          14              9
# 727        52              54                   0          10              4
# ..        ...             ...                 ...         ...            ...
# 554        68              38                   0          42             18
# 95         44              15                   0          10             33
# 890        51              39                   0           9              6
# 395        79              22                  13          14              3
# 136        53              18                   0          18             34
#
# [96 rows x 14 columns]

# %%
lm.fit(X_test,y_test)
# Out:
# C:\Users\Ayeni\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
prediction = lm.predict(X_test)

# %%
y
# Out:
# 0      141381703
# 1      133716286
# 2      140003974
# 3      800840817
# 4      303236322
#          ...
# 948     91473363
# 949    121871870
# 950     73513683
# 951    133895612
# 952     96007391
# Name: streams, Length: 953, dtype: object

# %%
prediction
# Out:
# array(['91221625', '429504768', '170413877', '123216717', '1457139296',
#        '104992946', '1210599487', '141720999', '782369383', '127026613',
#        '797402345', '191945597', '607123776', '42485571', '1260594497',
#        '91221625', '403939487', '51641685', '322336177', '2559529074',
#        '261116938', '1007612429', '156658366', '178660459', '282883169',
#        '1814349763', '2565529693', '115331792', '173627354', '195576623',
#        '283332261', '2159346687', '449701773', '694525298', '1065580332',
#        '887906111', '571386359', '720434240', '335074782', '496311364',
#        '121871870', '417230415', '227918678', '610045621', '91656026',
#        '349746291', '404664135', '506778838', '161460990', '37778188',
#        '426204830', '121077868', '362361576', '1440757818', '176290831',
#        '88092256', '319566866', '1591223784', '1163093654', '256483385',
#        '177503916', '939844851', '374706940', '273005485', '769213520',
#        '307370144', '2288695111', '90839753', '146363130', '86773632',
#        '1145727611', '191333656', '307752576', '258714692', '1367810478',
#        '74601456', '2887241814', '148469433', '1230855859', '41210087',
#        '2123309722', '673801126', '116599790', '14780425', '328207708',
#        '611994237', '53933526', '223582566', '422691058', '77233241',
#        '188933502', '1445941661', '227918678', '307752576', '789753877',
#        '276259178'], dtype=object)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
plt.scatter(y_test,prediction)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')
